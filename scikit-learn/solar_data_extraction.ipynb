# %%
# %pip install -U pandas
# %pip install -U numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

# %%
generation_data_1 = pd.read_csv("./solar_dataset/Plant_1_Generation_Data.csv")

# %%
generation_data_inverter_1 = generation_data_1[(generation_data_1["SOURCE_KEY"]=="1BY6WEcLGh8j5v7")]

# %%
display(generation_data_inverter_1)
# Out:
#               DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 0      15-05-2020 00:00   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 21     15-05-2020 00:15   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 42     15-05-2020 00:30   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 63     15-05-2020 00:45   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 84     15-05-2020 01:00   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# ...                 ...       ...              ...       ...       ...
# 68668  17-06-2020 22:45   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 68690  17-06-2020 23:00   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 68712  17-06-2020 23:15   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 68734  17-06-2020 23:30   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 68756  17-06-2020 23:45   4135001  1BY6WEcLGh8j5v7       0.0       0.0
#
#        DAILY_YIELD  TOTAL_YIELD
# 0              0.0    6259559.0
# 21             0.0    6259559.0
# ...

# %%
pip install "pymongo[srv]"
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pymongo import MongoClient
def get_database():
   # Provide the mongodb atlas url to connect python to mongodb using pymongo
   CONNECTION_STRING = "mongodb+srv://nimesh20221000:zQiXKdX7MBtXJqSA@equinoxdb.ivinrwy.mongodb.net/?retryWrites=true&w=majority"
 
   # Create a connection using MongoClient. You can import MongoClient or use pymongo.MongoClient
   client = MongoClient(CONNECTION_STRING)
 
   # Create the database for our example (we will use the same database throughout the tutorial
   return client['test']
  
# This is added so that many files can reuse the function get_database()
if __name__ == "__main__":   
  
   # Get the database
   dbname = get_database()

# %%
collection_name = dbname["mockdatas"]

# %%
import calendar
import time

# %%
dataList = []
for index, row in generation_data_inverter_1.iterrows():
    formattedDate = calendar.timegm(time.strptime(row['DATE_TIME'], '%d-%m-%Y %H:%M')) #15-05-2020 00:30
    print(formattedDate)
    item = { "dataItemMap":{ "radiation_intensity":"", "theory_power":"", "inverter_power":row['AC_POWER'], "ongrid_power":"", "power_profit":0 }, "stationCode":row['SOURCE_KEY'], "collectTime":formattedDate }
    dataList.append(item)
    print(item)
# Out:
# 1589500800
# {'dataItemMap': {'radiation_intensity': '', 'theory_power': '', 'inverter_power': 0.0, 'ongrid_power': '', 'power_profit': 0}, 'stationCode': '1BY6WEcLGh8j5v7', 'collectTime': 1589500800}
# 1589501700
# {'dataItemMap': {'radiation_intensity': '', 'theory_power': '', 'inverter_power': 0.0, 'ongrid_power': '', 'power_profit': 0}, 'stationCode': '1BY6WEcLGh8j5v7', 'collectTime': 1589501700}
# 1589502600
# {'dataItemMap': {'radiation_intensity': '', 'theory_power': '', 'inverter_power': 0.0, 'ongrid_power': '', 'power_profit': 0}, 'stationCode': '1BY6WEcLGh8j5v7', 'collectTime': 1589502600}
# 1589503500
# {'dataItemMap': {'radiation_intensity': '', 'theory_power': '', 'inverter_power': 0.0, 'ongrid_power': '', 'power_profit': 0}, 'stationCode': '1BY6WEcLGh8j5v7', 'collectTime': 1589503500}
# 1589504400
# ...

# %%
collection_name.insert_many(dataList)
# Out:
# InsertManyResult([ObjectId('65edd2eeffbe8006b33f8ac9'), ObjectId('65edd2eeffbe8006b33f8aca'), ObjectId('65edd2eeffbe8006b33f8acb'), ObjectId('65edd2eeffbe8006b33f8acc'), ObjectId('65edd2eeffbe8006b33f8acd'), ObjectId('65edd2eeffbe8006b33f8ace'), ObjectId('65edd2eeffbe8006b33f8acf'), ObjectId('65edd2eeffbe8006b33f8ad0'), ObjectId('65edd2eeffbe8006b33f8ad1'), ObjectId('65edd2eeffbe8006b33f8ad2'), ObjectId('65edd2eeffbe8006b33f8ad3'), ObjectId('65edd2eeffbe8006b33f8ad4'), ObjectId('65edd2eeffbe8006b33f8ad5'), ObjectId('65edd2eeffbe8006b33f8ad6'), ObjectId('65edd2eeffbe8006b33f8ad7'), ObjectId('65edd2eeffbe8006b33f8ad8'), ObjectId('65edd2eeffbe8006b33f8ad9'), ObjectId('65edd2eeffbe8006b33f8ada'), ObjectId('65edd2eeffbe8006b33f8adb'), ObjectId('65edd2eeffbe8006b33f8adc'), ObjectId('65edd2eeffbe8006b33f8add'), ObjectId('65edd2eeffbe8006b33f8ade'), ObjectId('65edd2eeffbe8006b33f8adf'), ObjectId('65edd2eeffbe8006b33f8ae0'), ObjectId('65edd2eeffbe8006b33f8ae1'), ObjectId('65edd2eeffbe8006b33f
# ...
